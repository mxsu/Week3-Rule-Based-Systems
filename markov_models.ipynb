# %% [markdown]
# <a href="https://colab.research.google.com/github/mxsu/Week3-Rule-Based-Systems/blob/main/markov_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/IAT-ComputationalCreativity-Spring2025/Week3-Rule-Based-Systems/blob/main/markov_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Markov Models Text Generation
#
# This notebook introduces Markov chains for text generation. We'll build a simple
# text generator that learns patterns from input text and generates new text with
# similar statistical properties.

# %%
# First, let's import our required libraries
from collections import defaultdict
import random

# %% [markdown]
# ## Building the Markov Chain
#
# A Markov chain represents sequences of states where the probability of each state
# depends only on the previous state(s). In our case, each state will be a sequence
# of words, and we'll predict the next word based on this sequence.

# %%
def build_markov_chain(text, order=2):
    """
    Build a Markov chain from input text.

    Args:
        text (str): Input text to learn from
        order (int): Number of words to use as state (context)

    Returns:
        dict: Mapping from state tuples to lists of possible next words
    """
    chain = defaultdict(list)
    words = text.split()

    for i in range(len(words) - order):
        # Create state tuple from current words
        state = tuple(words[i:i+order])
        # Get the next word
        next_word = words[i+order]
        # Add to chain
        chain[state].append(next_word)

    return chain

# %% [markdown]
# ## Generating Text
#
# Now we'll use our Markov chain to generate new text. We'll randomly select from
# the possible next words at each step.

# %%
def generate_text(chain, num_words=30):
    """
    Generate new text using the Markov chain.

    Args:
        chain (dict): Markov chain mapping states to possible next words
        order (int): Length of state tuples
        num_words (int): Number of words to generate

    Returns:
        str: Generated text
    """
    # Start with a random state from the chain
    words = list(random.choice(list(chain.keys())))
    order = len(list(chain.keys())[0])

    for _ in range(num_words - order):
        state = tuple(words[-order:])
        if state in chain:
            next_word = random.choice(chain[state])
            words.append(next_word)
        else:
            break

    return ' '.join(words)

# %% [markdown]
# ## Part 3: Basic Example
#
# Let's try our text generator with a simple example.

# %%
# Sample text
sample_text = """
The quick brown fox jumps over the lazy dog.
A quick brown dog jumps over the lazy fox.
The lazy fox sleeps while the quick brown dog watches.
"""

# Build the chain
chain = build_markov_chain(your_text)

# Examine the chain
for state, words in chain.items():
    print(f"{' '.join(state)} -> {words}")
# Out:
# Streaming output truncated to the last 5000 lines.
# amazing! It -> ['was']
# was the -> ['scariest,']
# the scariest, -> ['happiest']
# scariest, happiest -> ['moment']
# happiest moment -> ['of']
# moment of -> ['my']
# life. Humans! -> ['I']
# Humans! I -> ["can't"]
# believe you -> ['were']
# you were -> ['with', 'coming.', 'remodeling.']
# were with -> ['humans!']
# with humans! -> ['Giant,']
# humans! Giant, -> ['scary']
# Giant, scary -> ['humans!']
# scary humans! -> ['What']
# humans! What -> ['were']
# were they -> ['like?']
# they like? -> ['Huge']
# like? Huge -> ['and']
# Huge and -> ['crazy.']
# and crazy. -> ['They']
# crazy. They -> ['talk', 'eat']
# They talk -> ['crazy.']
# talk crazy. -> ['They']
# They eat -> ['crazy']
# eat crazy -> ['giant']
# crazy giant -> ['things.']
# giant things. -> ['They']
# things. They -> ['drive']
# They drive -> ['crazy.']
# drive crazy. -> ['Do']
# crazy. Do -> ['they']
# Do they -> ['try']
# they try -> ['and']
# try and -> ['kill']
# and kill -> ['you,']
# kill you, -> ['like']
# you, like -> ['on']
# like on -> ['TV?']
# on TV? -> ['Some']
# TV? Some -> ['of']
# Some of -> ['them.']
# of them. -> ['But']
# them. But -> ['some']
# But some -> ['of', 'bees']
# some of -> ['them']
# of them -> ["don't."]
# them don't. -> ["How'd"]
# don't. How'd -> ['you']
# How'd you -> ['get', 'like']
# you get -> ['back?', 'it?', 'in', 'mixed', 'a']
# get back? -> ['Poodle.']
# back? Poodle. -> ['You']
# Poodle. You -> ['did']
# did it, -> ['and']
# it, and -> ["I'm", "it's"]
# and I'm -> ['glad.']
# I'm glad. -> ['You']
# glad. You -> ['saw']
# You saw -> ['whatever']
# saw whatever -> ['you']
# whatever you -> ['wanted']
# you wanted -> ['to']
# to see. -> ['You']
# see. You -> ['had']
# You had -> ['your']
# had your -> ['"experience."']
# your "experience." -> ['Now']
# "experience." Now -> ['you']
# Now you -> ['can']
# can pick -> ['out']
# pick out -> ['yourjob']
# out yourjob -> ['and']
# yourjob and -> ['be']
# and be -> ['normal.']
# be normal. -> ['Well...']
# normal. Well... -> ['Well?']
# Well... Well? -> ['Well,']
# Well? Well, -> ['I']
# Well, I -> ['met', 'guess']
# I met -> ['someone.']
# met someone. -> ['You']
# someone. You -> ['did?']
# You did? -> ['Was']
# did? Was -> ['she']
# Was she -> ['Bee-ish?']
# she Bee-ish? -> ['A']
# Bee-ish? A -> ['wasp?!']
# A wasp?! -> ['Your']
# wasp?! Your -> ['parents']
# Your parents -> ['will']
# parents will -> ['kill']
# will kill -> ['you!']
# kill you! -> ['No,']
# you! No, -> ['no,']
# No, no, -> ['no,']
# no, no, -> ['not']
# no, not -> ['a']
# not a -> ['wasp.', 'tone.']
# a wasp. -> ['Spider?']
# wasp. Spider? -> ["I'm"]
# Spider? I'm -> ['not']
# not attracted -> ['to']
# attracted to -> ['spiders.']
# to spiders. -> ['I']
# spiders. I -> ['know']
# know it's -> ['the', 'got']
# it's the -> ['hottest']
# the hottest -> ['thing,']
# hottest thing, -> ['with']
# thing, with -> ['the']
# the eight -> ['legs']
# eight legs -> ['and']
# legs and -> ['all.']
# and all. -> ['I']
# all. I -> ["can't"]
# can't get -> ['by', 'them']
# get by -> ['that']
# by that -> ['face.']
# that face. -> ['So']
# face. So -> ['who']
# So who -> ['is']
# who is -> ['she?']
# is she? -> ["She's..."]
# she? She's... -> ['human.']
# She's... human. -> ['No,']
# human. No, -> ['no.']
# No, no. -> ["That's"]
# no. That's -> ['a']
# law. You -> ["wouldn't"]
# You wouldn't -> ['break']
# wouldn't break -> ['a']
# break a -> ['bee']
# law. Her -> ["name's"]
# Her name's -> ['Vanessa.']
# name's Vanessa. -> ['Oh,']
# Vanessa. Oh, -> ['boy.']
# Oh, boy. -> ["She's"]
# boy. She's -> ['so']
# She's so -> ['nice.']
# so nice. -> ['And']
# nice. And -> ["she's"]
# And she's -> ['a']
# she's a -> ['florist!']
# a florist! -> ['Oh,']
# florist! Oh, -> ['no!']
# no! You're -> ['dating']
# You're dating -> ['a']
# dating a -> ['human']
# a human -> ['florist!', 'girlfriend.', 'for']
# human florist! -> ["We're"]
# florist! We're -> ['not']
# We're not -> ['dating.', 'made']
# not dating. -> ["You're"]
# dating. You're -> ['flying']
# You're flying -> ['outside']
# flying outside -> ['The']
# Hive, talking -> ['to']
# to humans -> ['that']
# humans that -> ['attack']
# that attack -> ['our']
# attack our -> ['homes']
# our homes -> ['with']
# homes with -> ['power']
# with power -> ['washers']
# power washers -> ['and']
# washers and -> ['M-80s!']
# and M-80s! -> ['One-eighth']
# M-80s! One-eighth -> ['a']
# One-eighth a -> ['stick']
# a stick -> ['of']
# stick of -> ['dynamite!']
# of dynamite! -> ['She']
# dynamite! She -> ['saved']
# my life! -> ['And', 'Let']
# life! And -> ['she']
# And she -> ['understands']
# she understands -> ['me.']
# understands me. -> ['This']
# me. This -> ['is']
# is over! -> ['Eat']
# over! Eat -> ['this.']
# Eat this. -> ['This']
# this. This -> ['is']
# is not -> ['over!', 'the']
# not over! -> ['What']
# over! What -> ['was']
# that? They -> ['call']
# They call -> ['it']
# call it -> ['a']
# it a -> ['crumb.', 'little']
# crumb. It -> ['was']
# was so -> ["stingin'"]
# so stingin' -> ['stripey!']
# stingin' stripey! -> ['And']
# stripey! And -> ["that's"]
# And that's -> ['not']
# that's not -> ['what']
# not what -> ['they']
# what they -> ['eat.', 'eat!', "don't", 'do']
# they eat. -> ["That's"]
# eat. That's -> ['what']
# That's what -> ['falls']
# what falls -> ['off']
# falls off -> ['what']
# off what -> ['they']
# they eat! -> ['You']
# eat! You -> ['know']
# what a -> ['Cinnabon']
# a Cinnabon -> ['is?']
# Cinnabon is? -> ['No.']
# is? No. -> ["It's"]
# No. It's -> ['bread']
# It's bread -> ['and']
# bread and -> ['cinnamon']
# and cinnamon -> ['and']
# cinnamon and -> ['frosting.']
# and frosting. -> ['They']
# frosting. They -> ['heat']
# They heat -> ['it']
# heat it -> ['up...', 'up.', 'up,']
# it up... -> ['Sit']
# up... Sit -> ['down!']
# Sit down! -> ['...really']
# down! ...really -> ['hot!']
# ...really hot! -> ['Listen']
# hot! Listen -> ['to']
# Listen to -> ['me!', 'me!']
# me! We -> ['are']
# are not -> ['them!']
# not them! -> ["We're"]
# them! We're -> ['us.']
# We're us. -> ["There's"]
# us. There's -> ['us']
# There's us -> ['and']
# us and -> ["there's"]
# and there's -> ['them!', 'gallons']
# there's them! -> ['Yes,']
# them! Yes, -> ['but']
# Yes, but -> ['who']
# but who -> ['can']
# who can -> ['deny']
# can deny -> ['the']
# deny the -> ['heart']
# the heart -> ['that']
# heart that -> ['is']
# that is -> ['yearning?']
# is yearning? -> ["There's"]
# yearning? There's -> ['no']
# There's no -> ['yearning.']
# no yearning. -> ['Stop']
# yearning. Stop -> ['yearning.']
# Stop yearning. -> ['Listen']
# yearning. Listen -> ['to']
# me! You -> ['have']
# have got -> ['to', 'to']
# got to -> ['start', 'be', 'work.', 'think', 'start']
# to start -> ['thinking', 'thinking']
# start thinking -> ['bee,', 'bee?', 'bee,']
# thinking bee, -> ['my', 'my']
# bee, my -> ['friend.', 'friend.']
# my friend. -> ['Thinking', 'Thinking']
# friend. Thinking -> ['bee!', 'bee!']
# Thinking bee! -> ['Thinking', 'Thinking', 'Thinking', 'Thinking', 'There', 'Thinking', 'Thinking', 'Wait', 'Thinking', 'Thinking', 'What', 'Thinking', 'Thinking', 'Vanessa,', 'Me?']
# bee! Thinking -> ['bee.', 'bee!', 'bee!', 'bee!', 'bee!', 'bee!', 'bee!', 'bee!', 'bee!', 'bee!']
# Thinking bee. -> ['Thinking', 'Thinking', 'Thinking', 'Thinking']
# bee. Thinking -> ['bee.', 'bee!', 'bee.', 'bee!']
# bee! There -> ['he']
# There he -> ['is.']
# he is. -> ["He's"]
# is. He's -> ['in']
# He's in -> ['the']
# the pool. -> ['You']
# pool. You -> ['know']
# what your -> ['problem']
# your problem -> ['is,']
# problem is, -> ['Barry?']
# is, Barry? -> ['I']
# Barry? I -> ['gotta']
# gotta start -> ['thinking']
# thinking bee? -> ['How']
# bee? How -> ['much']
# How much -> ['longer', 'do', 'longer']
# much longer -> ['will', 'will']
# longer will -> ['this', 'we']
# will this -> ['go', 'nightmare']
# this go -> ['on?']
# go on? -> ["It's", 'They']
# on? It's -> ['been']
# It's been -> ['three']
# been three -> ['days!']
# three days! -> ['Why']
# days! Why -> ["aren't"]
# Why aren't -> ['you']
# aren't you -> ['working?']
# you working? -> ["I've"]
# working? I've -> ['got']
# of big -> ['life']
# big life -> ['decisions']
# life decisions -> ['to']
# decisions to -> ['think']
# to think -> ['about.', 'bee,']
# think about. -> ['What']
# about. What -> ['life?']
# What life? -> ['You']
# life? You -> ['have']
# have no -> ['life!', 'job.', 'pants.']
# no life! -> ['You']
# life! You -> ['have']
# no job. -> ["You're"]
# job. You're -> ['barely']
# You're barely -> ['a']
# barely a -> ['bee!']
# bee! Would -> ['it']
# Would it -> ['kill']
# it kill -> ['you']
# kill you -> ['to']
# you to -> ['make']
# make a -> ['little', 'call,']
# little honey? -> ['Barry,']
# honey? Barry, -> ['come']
# Barry, come -> ['out.']
# come out. -> ['Your']
# out. Your -> ["father's"]
# Your father's -> ['talking']
# father's talking -> ['to']
# to you. -> ['Martin,', 'Making']
# you. Martin, -> ['would']
# Martin, would -> ['you']
# you talk -> ['to']
# to him? -> ['Barry,']
# him? Barry, -> ["I'm"]
# Barry, I'm -> ['talking', 'sorry.']
# to you! -> ['You']
# you! You -> ['coming?']
# You coming? -> ['Got']
# coming? Got -> ['everything?']
# Got everything? -> ['All']
# everything? All -> ['set!']
# All set! -> ['Go']
# set! Go -> ['ahead.']
# Go ahead. -> ["I'll"]
# ahead. I'll -> ['catch']
# I'll catch -> ['up.']
# catch up. -> ["Don't"]
# up. Don't -> ['be']
# be too -> ['long.']
# too long. -> ['Watch', 'Do']
# long. Watch -> ['this!']
# Watch this! -> ['Vanessa!']
# this! Vanessa! -> ["We're"]
# Vanessa! We're -> ['still']
# We're still -> ['here.']
# still here. -> ['I']
# here. I -> ['told', 'sense']
# told you -> ['not', 'humans']
# you not -> ['to', 'only']
# not to -> ['yell', 'sting.', 'use']
# to yell -> ['at']
# yell at -> ['him.', 'me?']
# at him. -> ['He']
# him. He -> ["doesn't"]
# He doesn't -> ['respond']
# doesn't respond -> ['to']
# respond to -> ['yelling!']
# to yelling! -> ['Then']
# yelling! Then -> ['why']
# Then why -> ['yell']
# why yell -> ['at']
# at me? -> ['Because']
# me? Because -> ['you']
# Because you -> ["don't", "don't"]
# don't listen! -> ["I'm"]
# listen! I'm -> ['not']
# not listening -> ['to']
# to this. -> ['Sorry,']
# this. Sorry, -> ["I've"]
# Sorry, I've -> ['gotta']
# I've gotta -> ['go.', 'go']
# gotta go. -> ['Where']
# go. Where -> ['are']
# you going? -> ["I'm", 'To']
# going? I'm -> ['meeting']
# I'm meeting -> ['a']
# meeting a -> ['friend.']
# a friend. -> ['A']
# friend. A -> ['girl?']
# A girl? -> ['Is']
# girl? Is -> ['this']
# Is this -> ['why', 'what']
# this why -> ['you']
# why you -> ["can't"]
# you can't -> ['decide?']
# can't decide? -> ['Bye.']
# decide? Bye. -> ['I']
# just hope -> ["she's"]
# hope she's -> ['Bee-ish.']
# she's Bee-ish. -> ['They']
# Bee-ish. They -> ['have']
# They have -> ['a', 'presented']
# a huge -> ['parade', 'help.', 'mistake.']
# huge parade -> ['of']
# parade of -> ['flowers']
# of flowers -> ['every']
# flowers every -> ['year']
# every year -> ['in']
# year in -> ['Pasadena?']
# in Pasadena? -> ['To']
# Pasadena? To -> ['be']
# To be -> ['in', 'forcibly']
# the Tournament -> ['of']
# Tournament of -> ['Roses,', 'Roses', 'Roses.', 'Roses,']
# of Roses, -> ["that's", 'Pasadena,']
# Roses, that's -> ['every']
# that's every -> ["florist's"]
# every florist's -> ['dream!']
# florist's dream! -> ['Up']
# dream! Up -> ['on']
# Up on -> ['a']
# a float, -> ['surrounded']
# float, surrounded -> ['by']
# surrounded by -> ['flowers,']
# by flowers, -> ['crowds']
# flowers, crowds -> ['cheering.']
# crowds cheering. -> ['A']
# cheering. A -> ['tournament.']
# A tournament. -> ['Do']
# tournament. Do -> ['the']
# Do the -> ['roses']
# the roses -> ['compete', 'have']
# roses compete -> ['in']
# compete in -> ['athletic']
# in athletic -> ['events?']
# athletic events? -> ['No.']
# events? No. -> ['All']
# No. All -> ['right,']
# right, I've -> ['got']
# got one. -> ['How']
# one. How -> ['come']
# How come -> ['you']
# come you -> ["don't"]
# don't fly -> ['everywhere?']
# fly everywhere? -> ["It's"]
# everywhere? It's -> ['exhausting.', 'faster.']
# It's exhausting. -> ['Why']
# exhausting. Why -> ["don't"]
# Why don't -> ['you']
# don't you -> ['run']
# you run -> ['everywhere?']
# run everywhere? -> ["It's"]
# It's faster. -> ['Yeah,']
# faster. Yeah, -> ['OK,']
# Yeah, OK, -> ['I']
# OK, I -> ['see,', 'made']
# I see, -> ['I']
# see, I -> ['see.']
# I see. -> ['All']
# see. All -> ['right,']
# right, your -> ['turn.']
# your turn. -> ['TiVo.']
# turn. TiVo. -> ['You']
# TiVo. You -> ['can']
# can just -> ['freeze']
# just freeze -> ['live']
# freeze live -> ['TV?']
# live TV? -> ["That's"]
# TV? That's -> ['insane!']
# That's insane! -> ['You']
# insane! You -> ["don't"]
# don't have -> ['that?', 'enough', 'to', 'any']
# have that? -> ['We']
# that? We -> ['have']
# have Hivo, -> ['but']
# Hivo, but -> ["it's"]
# but it's -> ['a']
# it's a -> ['disease.', 'perfect']
# a disease. -> ["It's"]
# disease. It's -> ['a']
# a horrible, -> ['horrible']
# horrible, horrible -> ['disease.']
# horrible disease. -> ['Oh,']
# disease. Oh, -> ['my.']
# my. Dumb -> ['bees!']
# Dumb bees! -> ['You']
# bees! You -> ['must']
# You must -> ['want', 'meet']
# must want -> ['to']
# sting all -> ['those']
# all those -> ['jerks.']
# those jerks. -> ['We']
# jerks. We -> ['try']
# We try -> ['not']
# try not -> ['to', 'to']
# to sting. -> ["It's"]
# sting. It's -> ['usually']
# It's usually -> ['fatal']
# usually fatal -> ['for']
# fatal for -> ['us.']
# us. So -> ['you']
# So you -> ['have', 'can']
# you have -> ['to']
# to watch -> ['your']
# your temper. -> ['Very']
# temper. Very -> ['carefully.']
# Very carefully. -> ['You']
# carefully. You -> ['kick']
# You kick -> ['a']
# kick a -> ['wall,']
# a wall, -> ['take']
# wall, take -> ['a']
# a walk, -> ['write']
# walk, write -> ['an']
# write an -> ['angry']
# an angry -> ['letter']
# angry letter -> ['and']
# letter and -> ['throw']
# and throw -> ['it']
# throw it -> ['out.', 'in']
# out. Work -> ['through']
# Work through -> ['it']
# through it -> ['like']
# it like -> ['any', 'to']
# like any -> ['emotion:']
# any emotion: -> ['Anger,']
# emotion: Anger, -> ['jealousy,']
# Anger, jealousy, -> ['lust.']
# jealousy, lust. -> ['Oh,']
# lust. Oh, -> ['my']
# Oh, my -> ['goodness!']
# my goodness! -> ['Are']
# goodness! Are -> ['you']
# you OK? -> ['Yeah.', 'Yeah.']
# OK? Yeah. -> ['What', 'It']
# Yeah. What -> ['is']
# is wrong -> ['with']
# wrong with -> ['you?!']
# with you?! -> ["It's"]
# you?! It's -> ['a']
# a bug. -> ["He's"]
# bug. He's -> ['not']
# He's not -> ['bothering']
# not bothering -> ['anybody.']
# bothering anybody. -> ['Get']
# anybody. Get -> ['out']
# Get out -> ['of']
# of here, -> ['you']
# here, you -> ['creep!']
# you creep! -> ['What']
# creep! What -> ['was']
# that? A -> ['Pic']
# A Pic -> ["'N'"]
# Pic 'N' -> ['Save']
# 'N' Save -> ['circular?']
# Save circular? -> ['Yeah,']
# circular? Yeah, -> ['it']
# Yeah, it -> ['was.']
# it was. -> ['How']
# was. How -> ['did']
# you know? -> ['It']
# know? It -> ['felt']
# It felt -> ['like']
# felt like -> ['about']
# like about -> ['10', 'bees.']
# about 10 -> ['pages.']
# 10 pages. -> ['Seventy-five']
# pages. Seventy-five -> ['is']
# Seventy-five is -> ['pretty']
# is pretty -> ['much']
# pretty much -> ['our', 'pure']
# much our -> ['limit.']
# our limit. -> ["You've"]
# limit. You've -> ['really']
# You've really -> ['got']
# really got -> ['that']
# got that -> ['down']
# that down -> ['to']
# down to -> ['a']
# a science. -> ['I']
# science. I -> ['lost']
# a cousin -> ['to']
# cousin to -> ['Italian']
# to Italian -> ['Vogue.']
# Italian Vogue. -> ["I'll", 'Mamma']
# Vogue. I'll -> ['bet.']
# I'll bet. -> ['What']
# bet. What -> ['in']
# What in -> ['the', 'the']
# the name -> ['of']
# name of -> ['Mighty']
# of Mighty -> ['Hercules']
# Mighty Hercules -> ['is']
# Hercules is -> ['this?']
# is this? -> ['How', 'Oh,']
# this? How -> ['did']
# did this -> ['get']
# this get -> ['here?']
# get here? -> ['cute']
# here? cute -> ['Bee,']
# cute Bee, -> ['Golden']
# Bee, Golden -> ['Blossom,']
# Golden Blossom, -> ['Ray']
# Blossom, Ray -> ['Liotta']
# Ray Liotta -> ['Private']
# Liotta Private -> ['Select?']
# Private Select? -> ['Is']
# Select? Is -> ['he']
# Is he -> ['that']
# he that -> ['actor?']
# that actor? -> ['I']
# actor? I -> ['never']
# never heard -> ['of']
# heard of -> ['him.']
# of him. -> ['Why']
# him. Why -> ['is']
# Why is -> ['this', 'yogurt']
# is this -> ['here?', 'place?', 'what', 'plane']
# this here? -> ['For']
# here? For -> ['people.']
# For people. -> ['We']
# people. We -> ['eat']
# We eat -> ['it.']
# eat it. -> ['You']
# it. You -> ["don't", 'snap', 'snap']
# have enough -> ['food']
# enough food -> ['of']
# food of -> ['your']
# your own? -> ['Well,']
# own? Well, -> ['yes.']
# Well, yes. -> ['How']
# yes. How -> ['do']
# How do -> ['you', 'we', 'you', 'we']
# get it? -> ['Bees']
# it? Bees -> ['make']
# know who -> ['makes']
# who makes -> ['it!']
# makes it! -> ['And']
# it! And -> ["it's"]
# And it's -> ['hard', 'on', 'a']
# it's hard -> ['to']
# hard to -> ['make', 'concentrate']
# make it! -> ["There's"]
# it! There's -> ['heating,']
# There's heating, -> ['cooling,']
# heating, cooling, -> ['stirring.']
# cooling, stirring. -> ['You']
# You need -> ['a']
# need a -> ['whole']
# a whole -> ['Krelman']
# whole Krelman -> ['thing!']
# Krelman thing! -> ["It's"]
# thing! It's -> ['organic.']
# It's organic. -> ["It's"]
# organic. It's -> ['our-ganic!']
# It's our-ganic! -> ["It's"]
# our-ganic! It's -> ['just']
# just honey, -> ['Barry.']
# honey, Barry. -> ['Just']
# Barry. Just -> ['what?!']
# Just what?! -> ['Bees']
# what?! Bees -> ["don't"]
# Bees don't -> ['know', 'smoke.', 'smoke.', 'smoke!']
# know about -> ['this!']
# about this! -> ['This']
# this! This -> ['is']
# is stealing! -> ['A']
# stealing! A -> ['lot']
# A lot -> ['of', 'of']
# of stealing! -> ["You've"]
# stealing! You've -> ['taken']
# You've taken -> ['our']
# taken our -> ['homes,']
# our homes, -> ['schools,hospitals!']
# homes, schools,hospitals! -> ['This']
# schools,hospitals! This -> ['is']
# is all -> ['we', 'over,']
# all we -> ['have!', 'know,', 'do']
# we have! -> ['And']
# have! And -> ["it's"]
# it's on -> ['sale?!']
# on sale?! -> ["I'm"]
# sale?! I'm -> ['getting']
# I'm getting -> ['to', 'to', 'the']
# getting to -> ['the', 'the']
# the bottom -> ['of', 'of', 'from']
# bottom of -> ['this.', 'all']
# of this. -> ["I'm"]
# this. I'm -> ['getting']
# of all -> ['of', 'bee']
# all of -> ['this!']
# of this! -> ['Hey,']
# this! Hey, -> ['Hector.']
# Hey, Hector. -> ['You']
# Hector. You -> ['almost']
# You almost -> ['done?']
# almost done? -> ['Almost.']
# done? Almost. -> ['He']
# Almost. He -> ['is']
# He is -> ['here.']
# is here. -> ['I']
# I sense -> ['it.']
# sense it. -> ['Well,']
# it. Well, -> ['I']
# I'll go -> ['home']
# go home -> ['now']
# home now -> ['and']
# now and -> ['just']
# and just -> ['leave']
# just leave -> ['this']
# leave this -> ['nice']
# this nice -> ['honey']
# nice honey -> ['out,']
# honey out, -> ['with']
# out, with -> ['no']
# with no -> ['one', 'water.']
# no one -> ['around.']
# one around. -> ["You're"]
# around. You're -> ['busted,']
# You're busted, -> ['box']
# busted, box -> ['boy!']
# box boy! -> ['I']
# boy! I -> ['knew']
# I knew -> ['I', "I'd", 'you']
# knew I -> ['heard']
# heard something. -> ['So']
# something. So -> ['you']
# can talk! -> ['I']
# talk! I -> ['can']
# can talk. -> ['And']
# talk. And -> ['now']
# And now -> ["you'll", "they're", "we're"]
# now you'll -> ['start']
# you'll start -> ['talking!']
# start talking! -> ['Where']
# talking! Where -> ['you']
# Where you -> ['getting', 'headed?']
# you getting -> ['the']
# the sweet -> ['stuff?']
# sweet stuff? -> ["Who's"]
# stuff? Who's -> ['your']
# Who's your -> ['supplier?']
# your supplier? -> ['I']
# supplier? I -> ["don't"]
# don't understand. -> ['I']
# understand. I -> ['thought']
# thought we -> ['were']
# we were -> ['friends.', 'on']
# were friends. -> ['The']
# friends. The -> ['last']
# The last -> ['thing']
# last thing -> ['we']
# thing we -> ['want']
# we want -> ['to', 'back']
# do is -> ['upset', 'get', 'blend']
# is upset -> ['bees!']
# upset bees! -> ["You're"]
# bees! You're -> ['too']
# You're too -> ['late!']
# too late! -> ["It's"]
# late! It's -> ['ours']
# It's ours -> ['now!']
# ours now! -> ['You,']
# now! You, -> ['sir,']
# You, sir, -> ['have', 'will']
# sir, have -> ['crossed']
# have crossed -> ['the']
# crossed the -> ['wrong']
# the wrong -> ['sword!']
# wrong sword! -> ['You,']
# sword! You, -> ['sir,']
# sir, will -> ['be']
# be lunch -> ['for']
# lunch for -> ['my']
# for my -> ['iguana,', 'signal.']
# my iguana, -> ['Ignacio!']
# iguana, Ignacio! -> ['Where']
# Ignacio! Where -> ['is']
# Where is -> ['the', 'the', 'your', 'the', 'everybody?']
# honey coming -> ['from?']
# coming from? -> ['Tell']
# from? Tell -> ['me']
# Tell me -> ['where!']
# me where! -> ['Honey']
# where! Honey -> ['Farms!']
# Honey Farms! -> ['It', 'Crazy']
# Farms! It -> ['comes']
# It comes -> ['from']
# comes from -> ['Honey']
# from Honey -> ['Farms!']
# Farms! Crazy -> ['person!']
# Crazy person! -> ['What']
# person! What -> ['horrible']
# What horrible -> ['thing']
# horrible thing -> ['has']
# thing has -> ['happened']
# has happened -> ['here?', 'to']
# happened here? -> ['These', 'That', 'There']
# here? These -> ['faces,']
# These faces, -> ['they']
# faces, they -> ['never']
# never knew -> ['what']
# knew what -> ['hit']
# what hit -> ['them.']
# hit them. -> ['And']
# them. And -> ['now']
# now they're -> ['on']
# they're on -> ['the']
# the road -> ['to']
# road to -> ['nowhere!']
# to nowhere! -> ['Just']
# nowhere! Just -> ['keep']
# Just keep -> ['still.']
# keep still. -> ['What?']
# still. What? -> ["You're"]
# What? You're -> ['not']
# not dead? -> ['Do']
# dead? Do -> ['I']
# Do I -> ['look']
# I look -> ['dead?']
# look dead? -> ['They']
# dead? They -> ['will']
# They will -> ['wipe']
# will wipe -> ['anything']
# wipe anything -> ['that']
# anything that -> ['moves.']
# that moves. -> ['Where']
# moves. Where -> ['you']
# you headed? -> ['To']
# headed? To -> ['Honey']
# To Honey -> ['Farms.']
# Honey Farms. -> ['I']
# Farms. I -> ['am']
# I am -> ['onto', 'hit!']
# am onto -> ['something']
# onto something -> ['huge']
# something huge -> ['here.']
# huge here. -> ["I'm"]
# here. I'm -> ['going', 'just']
# to Alaska. -> ['Moose']
# Alaska. Moose -> ['blood,']
# Moose blood, -> ['crazy']
# blood, crazy -> ['stuff.']
# crazy stuff. -> ['Blows']
# stuff. Blows -> ['your']
# Blows your -> ['head']
# your head -> ['off!', 'out']
# head off! -> ["I'm"]
# off! I'm -> ['going']
# to Tacoma. -> ['And']
# Tacoma. And -> ['you?']
# And you? -> ['He']
# you? He -> ['really']
# He really -> ['is']
# really is -> ['dead.']
# is dead. -> ['All']
# dead. All -> ['right.']
# right. Uh-oh! -> ['What']
# Uh-oh! What -> ['is']
# is that?! -> ['Oh,']
# that?! Oh, -> ['no!']
# no! A -> ['wiper!']
# A wiper! -> ['Triple']
# wiper! Triple -> ['blade!']
# Triple blade! -> ['Triple']
# blade! Triple -> ['blade?']
# Triple blade? -> ['Jump']
# blade? Jump -> ['on!']
# Jump on! -> ["It's"]
# on! It's -> ['your']
# It's your -> ['only']
# your only -> ['chance,', 'hope?']
# only chance, -> ['bee!']
# chance, bee! -> ['Why']
# bee! Why -> ['does']
# does everything -> ['have']
# everything have -> ['to']
# be so -> ['doggone']
# so doggone -> ['clean?!']
# doggone clean?! -> ['How']
# clean?! How -> ['much']
# much do -> ['you']
# you people -> ['need']
# people need -> ['to']
# need to -> ['see?!', 'talk!', 'shut']
# to see?! -> ['Open']
# see?! Open -> ['your']
# Open your -> ['eyes!']
# your eyes! -> ['Stick']
# eyes! Stick -> ['your']
# Stick your -> ['head']
# head out -> ['the']
# out the -> ['window!', 'new']
# the window! -> ['From']
# window! From -> ['NPR']
# From NPR -> ['News']
# NPR News -> ['in']
# News in -> ['Washington,']
# in Washington, -> ["I'm"]
# Washington, I'm -> ['Carl']
# I'm Carl -> ['Kasell.']
# Carl Kasell. -> ['But']
# Kasell. But -> ["don't"]
# But don't -> ['kill']
# don't kill -> ['no']
# kill no -> ['more']
# no more -> ['bugs!', 'pollination,']
# more bugs! -> ['Bee!']
# bugs! Bee! -> ['Moose']
# Bee! Moose -> ['blood']
# Moose blood -> ['guy!!']
# blood guy!! -> ['You']
# guy!! You -> ['hear']
# You hear -> ['something?']
# hear something? -> ['Like']
# what? Like -> ['tiny']
# Like tiny -> ['screaming.']
# tiny screaming. -> ['Turn']
# screaming. Turn -> ['off']
# Turn off -> ['the']
# the radio. -> ['Whassup,']
# radio. Whassup, -> ['bee']
# Whassup, bee -> ['boy?']
# bee boy? -> ['Hey,']
# boy? Hey, -> ['Blood.']
# Hey, Blood. -> ['Just']
# Blood. Just -> ['a']
# Just a -> ['row', 'minute.']
# a row -> ['of']
# row of -> ['honey']
# honey jars, -> ['as']
# jars, as -> ['far']
# as far -> ['as']
# far as -> ['the']
# as the -> ['eye']
# the eye -> ['could']
# eye could -> ['see.']
# could see. -> ['Wow!']
# see. Wow! -> ['I']
# Wow! I -> ['assume']
# I assume -> ['wherever']
# assume wherever -> ['this']
# wherever this -> ['truck']
# this truck -> ['goes']
# truck goes -> ['is']
# goes is -> ['where']
# is where -> ["they're"]
# where they're -> ['getting']
# they're getting -> ['it.']
# getting it. -> ['I']
# mean, that -> ["honey's"]
# that honey's -> ['ours.']
# honey's ours. -> ['Bees']
# ours. Bees -> ['hang']
# Bees hang -> ['tight.']
# hang tight. -> ["We're"]
# tight. We're -> ['all']
# We're all -> ['jammed', 'aware']
# all jammed -> ['in.']
# jammed in. -> ["It's"]
# in. It's -> ['a']
# a close -> ['community.']
# close community. -> ['Not']
# community. Not -> ['us,']
# Not us, -> ['man.']
# us, man. -> ['We']
# man. We -> ['on']
# We on -> ['our']
# on our -> ['own.', 'side.']
# our own. -> ['Every']
# own. Every -> ['mosquito']
# Every mosquito -> ['on']
# mosquito on -> ['his']
# on his -> ['own.', 'way']
# his own. -> ['What']
# own. What -> ['if']
# What if -> ['you', "Montgomery's"]
# in trouble? -> ['You']
# trouble? You -> ['a']
# You a -> ['mosquito,']
# a mosquito, -> ['you', 'smack,']
# mosquito, you -> ['in']
# you in -> ['trouble.', 'this']
# trouble. Nobody -> ['likes']
# Nobody likes -> ['us.']
# likes us. -> ['They']
# us. They -> ['just']
# They just -> ['smack.']
# just smack. -> ['See']
# smack. See -> ['a']
# See a -> ['mosquito,']
# mosquito, smack, -> ['smack!']
# smack, smack! -> ['At']
# smack! At -> ['least']
# At least -> ["you're", 'we']
# least you're -> ['out']
# you're out -> ['in']
# out in -> ['the']
# the world. -> ['You', 'What']
# world. You -> ['must']
# must meet -> ['girls.']
# meet girls. -> ['Mosquito']
# girls. Mosquito -> ['girls']
# Mosquito girls -> ['try']
# girls try -> ['to']
# try to -> ['trade']
# to trade -> ['up,']
# trade up, -> ['get']
# up, get -> ['with']
# get with -> ['a']
# a moth, -> ['dragonfly.']
# moth, dragonfly. -> ['Mosquito']
# dragonfly. Mosquito -> ['girl']
# Mosquito girl -> ["don't"]
# girl don't -> ['want']
# want no -> ['mosquito.']
# no mosquito. -> ['You']
# mosquito. You -> ['got']
# be kidding -> ['me!']
# kidding me! -> ["Mooseblood's"]
# me! Mooseblood's -> ['about']
# Mooseblood's about -> ['to']
# to leave -> ['the']
# leave the -> ['building!']
# the building! -> ['So']
# building! So -> ['long,']
# So long, -> ['bee!']
# long, bee! -> ['Hey,']
# bee! Hey, -> ['guys!']
# Hey, guys! -> ['Mooseblood!']
# guys! Mooseblood! -> ['I']
# Mooseblood! I -> ['knew']
# knew I'd -> ['catch']
# I'd catch -> ["y'all"]
# catch y'all -> ['down']
# y'all down -> ['here.']
# down here. -> ['Did']
# here. Did -> ['you']
# Did you -> ['bring', 'ever', 'see']
# you bring -> ['your']
# bring your -> ['crazy']
# your crazy -> ['straw?']
# crazy straw? -> ['We']
# straw? We -> ['throw']
# We throw -> ['it']
# it in -> ['jars,', 'lip']
# in jars, -> ['slap']
# jars, slap -> ['a']
# slap a -> ['label']
# a label -> ['on']
# label on -> ['it,']
# on it, -> ['and']
# and it's -> ['pretty', 'greater']
# it's pretty -> ['much']
# much pure -> ['profit.']
# pure profit. -> ['What']
# profit. What -> ['is']
# this place? -> ['A']
# place? A -> ["bee's"]
# A bee's -> ['got']
# bee's got -> ['a']
# a brain -> ['the']
# brain the -> ['size']
# the size -> ['of']
# size of -> ['a']
# a pinhead. -> ['They']
# pinhead. They -> ['are']
# They are -> ['pinheads!']
# are pinheads! -> ['Pinhead.']
# pinheads! Pinhead. -> ['Check']
# Pinhead. Check -> ['out']
# the new -> ['smoker.']
# new smoker. -> ['Oh,']
# smoker. Oh, -> ['sweet.']
# Oh, sweet. -> ["That's"]
# sweet. That's -> ['the']
# the one -> ['you']
# one you -> ['want.']
# you want. -> ['The']
# want. The -> ['Thomas']
# The Thomas -> ['3000!']
# Thomas 3000! -> ['Smoker?']
# 3000! Smoker? -> ['Ninety']
# Smoker? Ninety -> ['puffs']
# Ninety puffs -> ['a']
# puffs a -> ['minute,']
# a minute, -> ['semi-automatic.']
# minute, semi-automatic. -> ['Twice']
# semi-automatic. Twice -> ['the']
# Twice the -> ['nicotine,']
# the nicotine, -> ['all']
# nicotine, all -> ['the']
# all the -> ['tar.', 'bees', 'time.', 'bee', 'time.', 'flowers']
# the tar. -> ['A']
# tar. A -> ['couple']
# A couple -> ['breaths']
# couple breaths -> ['of']
# breaths of -> ['this']
# this knocks -> ['them']
# knocks them -> ['right']
# them right -> ['out.']
# right out. -> ['They']
# out. They -> ['make']
# They make -> ['the']
# make the -> ['honey,', 'money.', 'honey,', 'money"?']
# the honey, -> ['and', 'and']
# honey, and -> ['we', 'we']
# and we -> ['make', 'make', 'can']
# we make -> ['the', 'the']
# the money. -> ['"They']
# money. "They -> ['make']
# "They make -> ['the']
# the money"? -> ['Oh,']
# money"? Oh, -> ['my!']
# my! What's -> ['going']
# What's going -> ['on?', 'on?']
# going on? -> ['Are', 'Where']
# on? Are -> ['you']
# Yeah. It -> ["doesn't"]
# It doesn't -> ['last', 'matter.']
# doesn't last -> ['too']
# last too -> ['long.']
# long. Do -> ['you']
# know you're -> ['in']
# you're in -> ['a']
# a fake -> ['hive']
# fake hive -> ['with']
# hive with -> ['fake']
# with fake -> ['walls?']
# fake walls? -> ['Our']
# walls? Our -> ['queen']
# Our queen -> ['was']
# was moved -> ['here.']
# moved here. -> ['We']
# here. We -> ['had']
# We had -> ['no']
# had no -> ['choice.', 'idea.']
# no choice. -> ['This']
# choice. This -> ['is']
# is your -> ['queen?', 'life', 'relationship', 'proof?', 'smoking', 'captain.']
# your queen? -> ["That's"]
# queen? That's -> ['a']
# a man -> ['in']
# man in -> ["women's"]
# in women's -> ['clothes!']
# women's clothes! -> ["That's"]
# clothes! That's -> ['a']
# a drag -> ['queen!']
# drag queen! -> ['What']
# queen! What -> ['is']
# this? Oh, -> ['no!']
# no! There's -> ['hundreds']
# There's hundreds -> ['of']
# hundreds of -> ['them!']
# of them! -> ['Bee', 'Fine!']
# them! Bee -> ['honey.']
# Bee honey. -> ['Our']
# Our honey -> ['is']
# honey is -> ['being', 'out']
# is being -> ['brazenly']
# being brazenly -> ['stolen']
# brazenly stolen -> ['on']
# stolen on -> ['a']
# a massive -> ['scale!']
# massive scale! -> ['This']
# scale! This -> ['is']
# is worse -> ['than']
# worse than -> ['anything', 'a']
# than anything -> ['bears']
# anything bears -> ['have']
# bears have -> ['done!']
# have done! -> ['I']
# done! I -> ['intend']
# I intend -> ['to']
# intend to -> ['do']
# do something. -> ['Oh,']
# something. Oh, -> ['Barry,']
# Oh, Barry, -> ['stop.']
# Barry, stop. -> ['Who']
# stop. Who -> ['told']
# Who told -> ['you']
# you humans -> ['are']
# humans are -> ['taking']
# are taking -> ['our']
# taking our -> ['honey?', 'honey,']
# our honey? -> ["That's", 'We', 'Who']
# honey? That's -> ['a']
# a rumor. -> ['Do']
# rumor. Do -> ['these']
# Do these -> ['look']
# these look -> ['like']
# look like -> ['rumors?']
# like rumors? -> ["That's"]
# rumors? That's -> ['a']
# a conspiracy -> ['theory.']
# conspiracy theory. -> ['These']
# theory. These -> ['are']
# are obviously -> ['doctored']
# obviously doctored -> ['photos.']
# doctored photos. -> ['How']
# photos. How -> ['did']
# get mixed -> ['up']
# mixed up -> ['in']
# up in -> ['this?']
# in this? -> ["He's"]
# this? He's -> ['been']
# He's been -> ['talking']
# been talking -> ['to']
# to humans. -> ['What?']
# humans. What? -> ['Talking']
# What? Talking -> ['to']
# Talking to -> ['humans?!']
# to humans?! -> ['He']
# humans?! He -> ['has']
# He has -> ['a']
# has a -> ['human', 'show']
# human girlfriend. -> ['And']
# girlfriend. And -> ['they']
# And they -> ['make']
# they make -> ['out!']
# make out! -> ['Make']
# out! Make -> ['out?']
# Make out? -> ['Barry!']
# out? Barry! -> ['We']
# Barry! We -> ['do']
# We do -> ['not.']
# do not. -> ['You']
# not. You -> ['wish']
# You wish -> ['you']
# wish you -> ['could.']
# you could. -> ['Whose']
# could. Whose -> ['side']
# Whose side -> ['are']
# side are -> ['you']
# you on? -> ['The']
# on? The -> ['bees!']
# The bees! -> ['I']
# bees! I -> ['dated']
# I dated -> ['a']
# dated a -> ['cricket']
# a cricket -> ['once']
# cricket once -> ['in']
# once in -> ['San']
# in San -> ['Antonio.']
# San Antonio. -> ['Those']
# Antonio. Those -> ['crazy']
# Those crazy -> ['legs']
# crazy legs -> ['kept']
# legs kept -> ['me']
# kept me -> ['up']
# me up -> ['all']
# up all -> ['night.']
# all night. -> ['Barry,']
# night. Barry, -> ['this']
# Barry, this -> ['is']
# is what -> ['you']
# what you -> ['want']
# do with -> ['your']
# with your -> ['life?', 'little']
# it for -> ['all']
# for all -> ['our']
# all our -> ['lives.']
# our lives. -> ['Nobody', 'Unfortunately,']
# lives. Nobody -> ['works']
# Nobody works -> ['harder']
# works harder -> ['than']
# harder than -> ['bees!']
# than bees! -> ['Dad,']
# bees! Dad, -> ['I']
# Dad, I -> ['remember']
# I remember -> ['you', 'that.', 'you.']
# remember you -> ['coming']
# you coming -> ['home']
# coming home -> ['so']
# home so -> ['overworked']
# so overworked -> ['your']
# overworked your -> ['hands']
# hands were -> ['still']
# were still -> ['stirring.']
# still stirring. -> ['You']
# You couldn't -> ['stop.']
# couldn't stop. -> ['I']
# stop. I -> ['remember']
# remember that. -> ['What']
# that. What -> ['right']
# What right -> ['do']
# right do -> ['they']
# do they -> ['have']
# they have -> ['to', 'a', 'the']
# to our -> ['honey?']
# honey? We -> ['live']
# We live -> ['on']
# live on -> ['two']
# on two -> ['cups']
# cups a -> ['year.']
# a year. -> ['They']
# year. They -> ['put']
# They put -> ['it']
# put it -> ['in']
# in lip -> ['balm']
# lip balm -> ['for']
# balm for -> ['no']
# for no -> ['reason']
# no reason -> ['whatsoever!']
# reason whatsoever! -> ['Even']
# whatsoever! Even -> ['if']
# Even if -> ["it's"]
# it's true, -> ['what']
# true, what -> ['can']
# what can -> ['one']
# can one -> ['bee']
# one bee -> ['do?']
# bee do? -> ['Sting']
# do? Sting -> ['them']
# Sting them -> ['where']
# them where -> ['it']
# where it -> ['really', 'matters.']
# it really -> ['hurts.', 'well.']
# really hurts. -> ['In']
# hurts. In -> ['the']
# In the -> ['face!']
# the face! -> ['The']
# face! The -> ['eye!']
# The eye! -> ['That']
# eye! That -> ['would']
# That would -> ['hurt.']
# would hurt. -> ['No.']
# hurt. No. -> ['Up']
# No. Up -> ['the']
# Up the -> ['nose?']
# the nose? -> ["That's"]
# nose? That's -> ['a']
# a killer. -> ["There's"]
# killer. There's -> ['only']
# There's only -> ['one']
# only one -> ['place']
# one place -> ['you', 'where']
# place you -> ['can']
# can sting -> ['the']
# sting the -> ['humans,']
# the humans, -> ['one', 'they']
# humans, one -> ['place']
# place where -> ['it']
# it matters. -> ['Hive']
# matters. Hive -> ['at']
# Hive at -> ['Five,']
# at Five, -> ['The']
# Five, The -> ["Hive's"]
# The Hive's -> ['only']
# Hive's only -> ['full-hour']
# only full-hour -> ['action']
# full-hour action -> ['news']
# action news -> ['source.']
# news source. -> ['No']
# source. No -> ['more']
# No more -> ['bee']
# more bee -> ['beards!']
# bee beards! -> ['With']
# beards! With -> ['Bob']
# With Bob -> ['Bumble']
# Bob Bumble -> ['at']
# Bumble at -> ['the']
# at the -> ['anchor', 'point', 'airport,', 'controls', 'flower!']
# the anchor -> ['desk.']
# anchor desk. -> ['Weather']
# desk. Weather -> ['with']
# Weather with -> ['Storm']
# with Storm -> ['Stinger.']
# Storm Stinger. -> ['Sports']
# Stinger. Sports -> ['with']
# Sports with -> ['Buzz']
# with Buzz -> ['Larvi.']
# Buzz Larvi. -> ['And']
# Larvi. And -> ['Jeanette']
# And Jeanette -> ['Chung.']
# Jeanette Chung. -> ['Good']
# Chung. Good -> ['evening.']
# Good evening. -> ["I'm"]
# evening. I'm -> ['Bob']
# I'm Bob -> ['Bumble.']
# Bob Bumble. -> ['And', 'We']
# Bumble. And -> ["I'm"]
# I'm Jeanette -> ['Ohung.']
# Jeanette Ohung. -> ['A']
# Ohung. A -> ['tri-county']
# A tri-county -> ['bee,']
# tri-county bee, -> ['Barry']
# bee, Barry -> ['Benson,']
# Barry Benson, -> ['intends', 'fresh']
# Benson, intends -> ['to']
# intends to -> ['sue']
# to sue -> ['the']
# sue the -> ['human', 'human']
# the human -> ['race', 'world', 'race.', 'race']
# human race -> ['for', 'took']
# race for -> ['stealing']
# for stealing -> ['our']
# stealing our -> ['honey,']
# our honey, -> ['packaging', 'you']
# honey, packaging -> ['it']
# packaging it -> ['and']
# and profiting -> ['from']
# profiting from -> ['it']
# from it -> ['illegally!']
# it illegally! -> ['Tomorrow']
# illegally! Tomorrow -> ['night']
# Tomorrow night -> ['on']
# night on -> ['Bee']
# on Bee -> ['Larry']
# Bee Larry -> ['King,']
# Larry King, -> ["we'll"]
# King, we'll -> ['have']
# we'll have -> ['three', 'just']
# have three -> ['former']
# three former -> ['queens']
# former queens -> ['here']
# queens here -> ['in']
# here in -> ['our', 'downtown']
# in our -> ['studio,']
# our studio, -> ['discussing']
# studio, discussing -> ['their']
# discussing their -> ['new']
# their new -> ['book,']
# new book, -> ['classy']
# book, classy -> ['Ladies,']
# classy Ladies, -> ['out']
# Ladies, out -> ['this']
# out this -> ['week']
# this week -> ['on']
# week on -> ['Hexagon.']
# on Hexagon. -> ['Tonight']
# Hexagon. Tonight -> ["we're"]
# Tonight we're -> ['talking']
# we're talking -> ['to']
# to Barry -> ['Benson.']
# Barry Benson. -> ['Did', 'From']
# Benson. Did -> ['you']
# ever think, -> ['"I\'m']
# think, "I'm -> ['a']
# "I'm a -> ['kid']
# a kid -> ['from']
# kid from -> ['The']
# from The -> ['Hive.']
# Hive. I -> ["can't"]
# do this"? -> ['Bees']
# this"? Bees -> ['have']
# Bees have -> ['never', 'good', '100']
# have never -> ['been', 'been']
# never been -> ['afraid', 'a', 'asked,']
# been afraid -> ['to']
# afraid to -> ['change']
# to change -> ['the']
# change the -> ['world.']
# world. What -> ['about', 'will']
# What about -> ['Bee']
# about Bee -> ['Oolumbus?']
# Bee Oolumbus? -> ['Bee']
# Oolumbus? Bee -> ['Gandhi?']
# Bee Gandhi? -> ['Bejesus?']
# Gandhi? Bejesus? -> ['Where']
# Bejesus? Where -> ["I'm"]
# Where I'm -> ['from,']
# I'm from, -> ["we'd"]
# from, we'd -> ['never']
# we'd never -> ['sue']
# never sue -> ['humans.']
# sue humans. -> ['We']
# humans. We -> ['were']
# We were -> ['thinking']
# of stickball -> ['or']
# stickball or -> ['candy']
# or candy -> ['stores.']
# candy stores. -> ['How']
# stores. How -> ['old']
# How old -> ['are']
# old are -> ['you?']
# you? The -> ['bee']
# The bee -> ['community']
# bee community -> ['is']
# community is -> ['supporting']
# is supporting -> ['you']
# supporting you -> ['in']
# in this -> ['case,', 'room', 'court!', 'court.', 'world.', 'park.', 'fairy']
# this case, -> ['which']
# case, which -> ['will']
# which will -> ['be']
# be the -> ['trial', 'nicest', 'princess,', 'pea!']
# the trial -> ['of']
# trial of -> ['the']
# bee century. -> ['You']
# century. You -> ['know,']
# know, they -> ['have']
# a Larry -> ['King']
# Larry King -> ['in']
# King in -> ['the']
# human world -> ['too.']
# world too. -> ["It's"]
# too. It's -> ['a']
# a common -> ['name.']
# common name. -> ['Next']
# name. Next -> ['week...']
# Next week... -> ['He', 'Glasses,']
# week... He -> ['looks']
# He looks -> ['like']
# looks like -> ['you', "we'll"]
# like you -> ['and']
# and has -> ['a']
# a show -> ['and']
# show and -> ['suspenders']
# and suspenders -> ['and']
# suspenders and -> ['colored']
# and colored -> ['dots...']
# colored dots... -> ['Next']
# dots... Next -> ['week...']
# week... Glasses, -> ['quotes']
# Glasses, quotes -> ['on']
# quotes on -> ['the']
# bottom from -> ['the']
# the guest -> ['even']
# guest even -> ['though']
# even though -> ['you']
# though you -> ['just']
# just heard -> ["'em."]
# heard 'em. -> ['Bear']
# 'em. Bear -> ['Week']
# Bear Week -> ['next']
# Week next -> ['week!']
# next week! -> ["They're"]
# week! They're -> ['scary,']
# They're scary, -> ['hairy']
# scary, hairy -> ['and']
# hairy and -> ['here']
# and here -> ['live.']
# here live. -> ['Always']
# live. Always -> ['leans']
# Always leans -> ['forward,']
# leans forward, -> ['pointy']
# forward, pointy -> ['shoulders,']
# pointy shoulders, -> ['squinty']
# shoulders, squinty -> ['eyes,']
# squinty eyes, -> ['very']
# eyes, very -> ['Jewish.']
# very Jewish. -> ['In']
# Jewish. In -> ['tennis,']
# In tennis, -> ['you']
# tennis, you -> ['attack']
# you attack -> ['at']
# attack at -> ['the']
# point of -> ['weakness!']
# of weakness! -> ['It']
# weakness! It -> ['was']
# was my -> ['grandmother,', 'new', 'new']
# my grandmother, -> ['Ken.']
# grandmother, Ken. -> ["She's"]
# Ken. She's -> ['81.']
# She's 81. -> ['Honey,']
# 81. Honey, -> ['her']
# Honey, her -> ["backhand's"]
# her backhand's -> ['a']
# backhand's a -> ['joke!']
# a joke! -> ["I'm"]
# joke! I'm -> ['not']
# not gonna -> ['take']
# take advantage -> ['of']
# advantage of -> ['that?']
# of that? -> ['Quiet,']
# that? Quiet, -> ['please.']
# Quiet, please. -> ['Actual']
# please. Actual -> ['work']
# Actual work -> ['going']
# work going -> ['on']
# going on -> ['here.']
# on here. -> ['Is']
# here. Is -> ['that']
# that that -> ['same']
# same bee? -> ['Yes,']
# bee? Yes, -> ['it']
# Yes, it -> ['is!', 'kind']
# it is! -> ["I'm"]
# is! I'm -> ['helping']
# I'm helping -> ['him']
# helping him -> ['sue']
# him sue -> ['the']
# human race. -> ['Hello.']
# race. Hello. -> ['Hello,']
# Hello. Hello, -> ['bee.']
# Hello, bee. -> ['This']
# bee. This -> ['is']
# is Ken. -> ['Yeah,']
# Ken. Yeah, -> ['I']
# Yeah, I -> ['remember']
# remember you. -> ['Timberland,']
# you. Timberland, -> ['size']
# Timberland, size -> ['ten']
# size ten -> ['and']
# ten and -> ['a']
# a half. -> ['Vibram']
# half. Vibram -> ['sole,']
# Vibram sole, -> ['I']
# sole, I -> ['believe.']
# I believe. -> ['Why']
# believe. Why -> ['does']
# does he -> ['talk']
# he talk -> ['again?']
# talk again? -> ['Listen,']
# again? Listen, -> ['you']
# Listen, you -> ['better']
# you better -> ['go']
# better go -> ["'cause"]
# go 'cause -> ["we're"]
# 'cause we're -> ['really', 'the']
# we're really -> ['busy']
# really busy -> ['working.']
# busy working. -> ['But']
# working. But -> ["it's"]
# But it's -> ['our', 'just']
# it's our -> ['yogurt']
# our yogurt -> ['night!']
# yogurt night! -> ['Bye-bye.']
# night! Bye-bye. -> ['Why']
# Bye-bye. Why -> ['is']
# is yogurt -> ['night']
# yogurt night -> ['so']
# night so -> ['difficult?!']
# so difficult?! -> ['You']
# difficult?! You -> ['poor']
# You poor -> ['thing.']
# poor thing. -> ['You']
# You two -> ['have']
# two have -> ['been']
# have been -> ['at', 'felled', 'helping']
# been at -> ['this']
# at this -> ['for']
# this for -> ['hours!']
# for hours! -> ['Yes,']
# hours! Yes, -> ['and']
# Yes, and -> ['Adam']
# and Adam -> ['here']
# Adam here -> ['has']
# here has -> ['been']
# been a -> ['huge', 'police']
# huge help. -> ['Frosting...']
# help. Frosting... -> ['How']
# Frosting... How -> ['many']
# How many -> ['sugars?']
# many sugars? -> ['Just']
# sugars? Just -> ['one.']
# Just one. -> ['I']
# one. I -> ['try']
# I try -> ['not']
# to use -> ['the']
# use the -> ['competition.']
# the competition. -> ['So']
# competition. So -> ['why']
# So why -> ['are']
# why are -> ['you']
# you helping -> ['me?']
# helping me? -> ['Bees']
# me? Bees -> ['have']
# have good -> ['qualities.', 'lawyers?']
# good qualities. -> ['And']
# qualities. And -> ['it']
# And it -> ['takes']
# it takes -> ['my']
# takes my -> ['mind']
# my mind -> ['off']
# mind off -> ['the']
# the shop. -> ['Instead']
# shop. Instead -> ['of']
# Instead of -> ['flowers,']
# of flowers, -> ['people']
# flowers, people -> ['are']
# people are -> ['giving']
# are giving -> ['balloon']
# giving balloon -> ['bouquets']
# balloon bouquets -> ['now.']
# bouquets now. -> ['Those']
# now. Those -> ['are']
# Those are -> ['great,']
# are great, -> ['if']
# great, if -> ["you're"]
# if you're -> ['three.']
# you're three. -> ['And']
# three. And -> ['artificial']
# And artificial -> ['flowers.']
# artificial flowers. -> ['Oh,']
# flowers. Oh, -> ['those']
# Oh, those -> ['just']
# those just -> ['get']
# just get -> ['me']
# get me -> ['psychotic!']
# me psychotic! -> ['Yeah,']
# psychotic! Yeah, -> ['me']
# Yeah, me -> ['too.']
# me too. -> ['Bent']
# too. Bent -> ['stingers,']
# Bent stingers, -> ['pointless']
# stingers, pointless -> ['pollination.']
# pointless pollination. -> ['Bees']
# pollination. Bees -> ['must']
# Bees must -> ['hate']
# must hate -> ['those']
# hate those -> ['fake']
# those fake -> ['things!']
# fake things! -> ['Nothing']
# things! Nothing -> ['worse']
# Nothing worse -> ['than']
# than a -> ['daffodil', 'prance-about', 'filthy,', 'big']
# a daffodil -> ["that's"]
# daffodil that's -> ['had']
# that's had -> ['work']
# had work -> ['done.']
# work done. -> ['Maybe']
# done. Maybe -> ['this']
# this could -> ['make']
# could make -> ['up']
# make up -> ['for']
# for it -> ['a']
# little bit. -> ['This']
# bit. This -> ["lawsuit's"]
# This lawsuit's -> ['a']
# lawsuit's a -> ['pretty']
# a pretty -> ['big']
# pretty big -> ['deal.']
# big deal. -> ['I']
# deal. I -> ['guess.']
# guess. You -> ['sure']
# You sure -> ['you']
# sure you -> ['want']
# go through -> ['with']
# through with -> ['it?']
# with it? -> ['Am']
# it? Am -> ['I']
# Am I -> ['sure?', 'koo-koo-kachoo,']
# I sure? -> ['When']
# sure? When -> ["I'm"]
# When I'm -> ['done']
# I'm done -> ['with']
# done with -> ['the']
# humans, they -> ["won't"]
# they won't -> ['be']
# won't be -> ['able']
# to say, -> ['"Honey,']
# say, "Honey, -> ["I'm"]
# "Honey, I'm -> ['home,"']
# I'm home," -> ['without']
# home," without -> ['paying']
# without paying -> ['a']
# paying a -> ['royalty!']
# a royalty! -> ["It's"]
# royalty! It's -> ['an']
# It's an -> ['incredible']
# an incredible -> ['scene']
# incredible scene -> ['here']
# scene here -> ['in']
# in downtown -> ['Manhattan,']
# downtown Manhattan, -> ['where']
# Manhattan, where -> ['the']
# where the -> ['world']
# the world -> ['anxiously', 'is']
# world anxiously -> ['waits,']
# anxiously waits, -> ['because']
# waits, because -> ['for']
# because for -> ['the']
# the first -> ['time']
# first time -> ['in']
# time in -> ['history,']
# in history, -> ['we']
# history, we -> ['will']
# we will -> ['hear', 'no']
# will hear -> ['for']
# hear for -> ['ourselves']
# for ourselves -> ['if']
# ourselves if -> ['a']
# if a -> ['honeybee']
# a honeybee -> ['can']
# honeybee can -> ['actually']
# can actually -> ['speak.']
# actually speak. -> ['What']
# speak. What -> ['have']
# What have -> ['we']
# have we -> ['gotten']
# we gotten -> ['into']
# gotten into -> ['here,']
# into here, -> ['Barry?']
# here, Barry? -> ["It's"]
# Barry? It's -> ['pretty']
# It's pretty -> ['big,']
# pretty big, -> ["isn't"]
# big, isn't -> ['it?']
# isn't it? -> ['I']
# believe how -> ['many', 'much', 'lucky']
# how many -> ['humans']
# many humans -> ["don't"]
# humans don't -> ['work']
# don't work -> ['during']
# work during -> ['the']
# during the -> ['day.']
# day. You -> ['think']
# You think -> ['billion-dollar', 'I', 'it']
# think billion-dollar -> ['multinational']
# billion-dollar multinational -> ['food']
# multinational food -> ['companies']
# food companies -> ['have', 'collectively?']
# companies have -> ['good']
# good lawyers? -> ['Everybody']
# lawyers? Everybody -> ['needs']
# Everybody needs -> ['to']
# needs to -> ['stay', 'make']
# to stay -> ['behind']
# stay behind -> ['the']
# behind the -> ['barricade.']
# the barricade. -> ["What's"]
# barricade. What's -> ['the']
# the matter? -> ['I']
# matter? I -> ["don't"]
# know, I -> ['just', "don't"]
# just got -> ['a', 'this']
# a chill. -> ['Well,']
# chill. Well, -> ['if']
# Well, if -> ['it']
# it isn't -> ['the']
# isn't the -> ['bee']
# bee team. -> ['You']
# team. You -> ['boys']
# You boys -> ['work']
# boys work -> ['on']
# on this? -> ['All']
# this? All -> ['rise!']
# All rise! -> ['The']
# rise! The -> ['Honorable']
# The Honorable -> ['Judge']
# Honorable Judge -> ['Bumbleton']
# Judge Bumbleton -> ['presiding.']
# Bumbleton presiding. -> ['All']
# presiding. All -> ['right.']
# right. Case -> ['number']
# Case number -> ['4475,']
# number 4475, -> ['Superior']
# 4475, Superior -> ['Court']
# Superior Court -> ['of']
# Court of -> ['New']
# of New -> ['York,']
# New York, -> ['Barry']
# York, Barry -> ['Bee']
# Barry Bee -> ['Benson']
# Bee Benson -> ['v.']
# Benson v. -> ['the']
# v. the -> ['Honey']
# the Honey -> ['Industry']
# Honey Industry -> ['is']
# Industry is -> ['now']
# is now -> ['in']
# now in -> ['session.']
# in session. -> ['Mr.']
# session. Mr. -> ['Montgomery,']
# Mr. Montgomery, -> ["you're", 'your']
# Montgomery, you're -> ['representing']
# you're representing -> ['the', 'all']
# representing the -> ['five']
# the five -> ['food']
# five food -> ['companies']
# companies collectively? -> ['A']
# collectively? A -> ['privilege.']
# A privilege. -> ['Mr.']
# privilege. Mr. -> ['Benson...']
# Mr. Benson... -> ["you're"]
# Benson... you're -> ['representing']
# representing all -> ['the']
# the bees -> ['of', 'yesterday']
# bees of -> ['the']
# the world? -> ["I'm"]
# world? I'm -> ['kidding.']
# I'm kidding. -> ['Yes,']
# kidding. Yes, -> ['Your']
# Yes, Your -> ['Honor,', 'Honor!']
# Your Honor, -> ["we're", "it's", "haven't"]
# Honor, we're -> ['ready']
# we're ready -> ['to']
# ready to -> ['proceed.', 'blow.']
# to proceed. -> ['Mr.']
# proceed. Mr. -> ['Montgomery,']
# Montgomery, your -> ['opening']
# your opening -> ['statement,']
# opening statement, -> ['please.']
# statement, please. -> ['Ladies']
# please. Ladies -> ['and']
# Ladies and -> ['gentlemen', 'gentlemen,', 'gentlemen,']
# and gentlemen -> ['of']
# gentlemen of -> ['the']
# the jury, -> ['my']
# jury, my -> ['grandmother']
# my grandmother -> ['was']
# grandmother was -> ['a']
# a simple -> ['woman.']
# simple woman. -> ['Born']
# woman. Born -> ['on']
# Born on -> ['a']
# a farm, -> ['she']
# farm, she -> ['believed']
# she believed -> ['it']
# believed it -> ['was']
# was man's -> ['divine']
# man's divine -> ['right']
# divine right -> ['to']
# right to -> ['benefit']
# to benefit -> ['from']
# benefit from -> ['the']
# the bounty -> ['of']
# bounty of -> ['nature']
# of nature -> ['God']
# nature God -> ['put']
# God put -> ['before']
# put before -> ['us.']
# before us. -> ['If']
# us. If -> ['we']
# we lived -> ['in']
# lived in -> ['the']
# the topsy-turvy -> ['world']
# topsy-turvy world -> ['Mr.']
# world Mr. -> ['Benson']
# Mr. Benson -> ['imagines,', 'Bee,', 'and']
# Benson imagines, -> ['just']
# imagines, just -> ['think']
# just think -> ['of']
# think of -> ['what']
# ...
# his no-account -> ['compadres.']
# no-account compadres. -> ["They've"]
# compadres. They've -> ['done']
# They've done -> ['enough']
# done enough -> ['damage.']
# enough damage. -> ['But']
# damage. But -> ["isn't"]
# But isn't -> ['he']
# isn't he -> ['your']
# he your -> ['only']
# only hope? -> ['Technically,']
# hope? Technically, -> ['a']
# Technically, a -> ['bee']
# bee shouldn't -> ['be']
# shouldn't be -> ['able']
# fly at -> ['all.']
# at all. -> ['Their']
# all. Their -> ['wings']
# Their wings -> ['are']
# too small... -> ["Haven't"]
# small... Haven't -> ['we']
# Haven't we -> ['heard']
# we heard -> ['this']
# heard this -> ['a']
# this a -> ['million']
# a million -> ['times?']
# million times? -> ['"The']
# times? "The -> ['surface']
# "The surface -> ['area']
# surface area -> ['of']
# area of -> ['the']
# the wings -> ['and', 'of']
# wings and -> ['body']
# and body -> ['mass']
# body mass -> ['make']
# mass make -> ['no']
# make no -> ['sense."']
# no sense." -> ['Get']
# sense." Get -> ['this']
# Get this -> ['on']
# this on -> ['the']
# the air! -> ['Got']
# air! Got -> ['it.']
# Got it. -> ['Stand']
# it. Stand -> ['by.']
# Stand by. -> ["We're"]
# by. We're -> ['going']
# going live. -> ['The']
# live. The -> ['way']
# The way -> ['we']
# way we -> ['work']
# we work -> ['may']
# work may -> ['be']
# may be -> ['a']
# a mystery -> ['to']
# mystery to -> ['you.']
# you. Making -> ['honey']
# Making honey -> ['takes']
# honey takes -> ['a']
# takes a -> ['lot']
# of bees -> ['doing']
# bees doing -> ['a']
# doing a -> ['lot']
# of small -> ['jobs.']
# small jobs. -> ['But']
# jobs. But -> ['let']
# But let -> ['me']
# a small -> ['job.']
# small job. -> ['If']
# job. If -> ['you']
# it well, -> ['it']
# well, it -> ['makes']
# it makes -> ['a']
# makes a -> ['big']
# big difference. -> ['More']
# difference. More -> ['than']
# More than -> ['we']
# than we -> ['realized.']
# we realized. -> ['To']
# realized. To -> ['us,']
# To us, -> ['to']
# us, to -> ['everyone.']
# to everyone. -> ["That's"]
# everyone. That's -> ['why']
# why I -> ['want']
# get bees -> ['back']
# bees back -> ['to']
# to working -> ['together.']
# working together. -> ["That's"]
# together. That's -> ['the']
# bee way! -> ["We're"]
# way! We're -> ['not']
# not made -> ['of']
# made of -> ['Jell-O.', 'millions']
# of Jell-O. -> ['We']
# Jell-O. We -> ['get']
# We get -> ['behind']
# get behind -> ['a', 'this', 'a']
# behind a -> ['fellow.', 'fellow.']
# a fellow. -> ['Black', 'Black']
# fellow. Black -> ['and', 'and']
# Hello! Left, -> ['right,']
# Left, right, -> ['down,']
# right, down, -> ['hover.']
# down, hover. -> ['Hover?']
# hover. Hover? -> ['Forget']
# Hover? Forget -> ['hover.']
# Forget hover. -> ['This']
# hover. This -> ["isn't"]
# isn't so -> ['hard.']
# so hard. -> ['Beep-beep!']
# hard. Beep-beep! -> ['Beep-beep!']
# Beep-beep! Beep-beep! -> ['Barry,']
# Beep-beep! Barry, -> ['what']
# what happened?! -> ['Wait,']
# happened?! Wait, -> ['I']
# Wait, I -> ['think']
# were on -> ['autopilot']
# on autopilot -> ['the']
# autopilot the -> ['whole']
# whole time. -> ['That']
# time. That -> ['may']
# That may -> ['have']
# may have -> ['been']
# been helping -> ['me.']
# helping me. -> ['And']
# now we're -> ['not!']
# we're not! -> ['So']
# not! So -> ['it']
# So it -> ['turns']
# it turns -> ['out']
# turns out -> ['I']
# out I -> ['cannot']
# I cannot -> ['fly']
# plane. All -> ['of']
# you, let's -> ['get']
# let's get -> ['behind']
# behind this -> ['fellow!']
# this fellow! -> ['Move']
# fellow! Move -> ['it']
# Move it -> ['out!']
# out! Move -> ['out!']
# Move out! -> ['Our']
# out! Our -> ['only']
# Our only -> ['chance']
# only chance -> ['is']
# chance is -> ['if']
# is if -> ['I']
# if I -> ['do']
# I do -> ['what']
# do what -> ["I'd"]
# what I'd -> ['do,']
# I'd do, -> ['you']
# do, you -> ['copy']
# you copy -> ['me']
# copy me -> ['with']
# me with -> ['the']
# wings of -> ['the']
# plane! Don't -> ['have']
# Don't have -> ['to']
# to yell. -> ["I'm"]
# yell. I'm -> ['not']
# not yelling! -> ["We're"]
# yelling! We're -> ['in']
# We're in -> ['a']
# of trouble. -> ["It's"]
# It's very -> ['hard']
# very hard -> ['to']
# to concentrate -> ['with']
# concentrate with -> ['that']
# that panicky -> ['tone']
# panicky tone -> ['in']
# tone in -> ['your']
# your voice! -> ["It's"]
# voice! It's -> ['not']
# a tone. -> ["I'm"]
# tone. I'm -> ['panicking!']
# I'm panicking! -> ['I']
# panicking! I -> ["can't"]
# do this! -> ['Vanessa,']
# this! Vanessa, -> ['pull']
# Vanessa, pull -> ['yourself']
# pull yourself -> ['together.']
# yourself together. -> ['You']
# together. You -> ['have']
# to snap -> ['out']
# snap out -> ['of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of']
# of it! -> ['You', 'You', 'You', 'You', 'You', 'You', 'Hold']
# it! You -> ['snap', 'snap', 'snap', 'snap', 'snap', 'snap', 'taught']
# You snap -> ['out', 'out', 'out', 'out', 'out', 'out', 'out', 'out']
# it! Hold -> ['it!']
# Hold it! -> ['Why?']
# it! Why? -> ['Come']
# Why? Come -> ['on,']
# Come on, -> ["it's", 'already.']
# on, it's -> ['my']
# it's my -> ['turn.']
# my turn. -> ['How']
# turn. How -> ['is']
# How is -> ['the']
# the plane -> ['flying?']
# plane flying? -> ['I']
# flying? I -> ["don't"]
# know. Hello? -> ['Benson,']
# Hello? Benson, -> ['got']
# Benson, got -> ['any']
# got any -> ['flowers']
# any flowers -> ['for']
# flowers for -> ['a']
# a happy -> ['occasion']
# happy occasion -> ['in']
# occasion in -> ['there?']
# in there? -> ['The']
# there? The -> ['Pollen']
# The Pollen -> ['Jocks!']
# Jocks! They -> ['do']
# They do -> ['get']
# do get -> ['behind']
# and yellow. -> ['Hello.']
# yellow. Hello. -> ['All']
# Hello. All -> ['right,']
# right, let's -> ['drop']
# let's drop -> ['this']
# drop this -> ['tin']
# this tin -> ['can']
# tin can -> ['on']
# can on -> ['the']
# the blacktop. -> ['Where?']
# blacktop. Where? -> ['I']
# Where? I -> ["can't"]
# can't see -> ['anything.']
# see anything. -> ['Can']
# anything. Can -> ['you?']
# Can you? -> ['No,']
# No, nothing. -> ["It's"]
# It's all -> ['cloudy.']
# all cloudy. -> ['Come']
# cloudy. Come -> ['on.']
# Come on. -> ['You']
# on. You -> ['got']
# think bee, -> ['Barry.']
# bee, Barry. -> ['Thinking']
# Barry. Thinking -> ['bee.']
# bee! Wait -> ['a']
# minute. I -> ['think']
# think I'm -> ['feeling']
# feeling something. -> ['What?']
# something. What? -> ['I']
# What? I -> ["don't"]
# know. It's -> ['strong,']
# It's strong, -> ['pulling']
# strong, pulling -> ['me.']
# pulling me. -> ['Like']
# me. Like -> ['a']
# Like a -> ['27-million-year-old']
# a 27-million-year-old -> ['instinct.']
# 27-million-year-old instinct. -> ['Bring']
# instinct. Bring -> ['the']
# Bring the -> ['nose']
# the nose -> ['down.']
# nose down. -> ['Thinking']
# down. Thinking -> ['bee!']
# bee! What -> ['in']
# world is -> ['on']
# is on -> ['the']
# the tarmac? -> ['Get']
# tarmac? Get -> ['some']
# Get some -> ['lights']
# some lights -> ['on']
# lights on -> ['that!']
# on that! -> ['Thinking']
# that! Thinking -> ['bee!']
# bee! Vanessa, -> ['aim']
# Vanessa, aim -> ['for']
# aim for -> ['the']
# the flower. -> ['OK.']
# flower. OK. -> ['Cut']
# OK. Cut -> ['the']
# Cut the -> ['engines.']
# the engines. -> ["We're"]
# engines. We're -> ['going']
# going in -> ['on']
# in on -> ['bee']
# on bee -> ['power.']
# bee power. -> ['Ready,']
# power. Ready, -> ['boys?']
# Ready, boys? -> ['Affirmative!']
# boys? Affirmative! -> ['Good.']
# Affirmative! Good. -> ['Good.']
# Good. Good. -> ['Easy,']
# Good. Easy, -> ['now.']
# Easy, now. -> ["That's"]
# now. That's -> ['it.']
# That's it. -> ['Land']
# it. Land -> ['on']
# Land on -> ['that']
# that flower! -> ['Ready?', 'The']
# flower! Ready? -> ['Full']
# Ready? Full -> ['reverse!']
# Full reverse! -> ['Spin', 'Just']
# reverse! Spin -> ['it']
# Spin it -> ['around!']
# it around! -> ['Not']
# around! Not -> ['that']
# Not that -> ['flower!']
# flower! The -> ['other']
# The other -> ['one!']
# other one! -> ['Which']
# one! Which -> ['one?']
# Which one? -> ['That']
# one? That -> ['flower.']
# That flower. -> ["I'm"]
# flower. I'm -> ['aiming']
# I'm aiming -> ['at']
# aiming at -> ['the']
# the flower! -> ["That's", 'That']
# flower! That's -> ['a']
# a fat -> ['guy']
# fat guy -> ['in']
# guy in -> ['a']
# a flowered -> ['shirt.']
# flowered shirt. -> ['I']
# shirt. I -> ['mean']
# I mean -> ['the']
# mean the -> ['giant']
# the giant -> ['pulsating', 'flower?']
# giant pulsating -> ['flower']
# pulsating flower -> ['made']
# flower made -> ['of']
# of millions -> ['of']
# millions of -> ['bees!']
# bees! Pull -> ['forward.']
# Pull forward. -> ['Nose']
# forward. Nose -> ['down.']
# Nose down. -> ['Tail']
# down. Tail -> ['up.']
# Tail up. -> ['Rotate']
# up. Rotate -> ['around']
# Rotate around -> ['it.']
# around it. -> ['This']
# is insane, -> ['Barry!']
# insane, Barry! -> ["This's"]
# Barry! This's -> ['the']
# This's the -> ['only']
# only way -> ['I']
# way I -> ['know']
# how to -> ['fly.', 'fly!']
# fly. Am -> ['I']
# I koo-koo-kachoo, -> ['or']
# koo-koo-kachoo, or -> ['is']
# or is -> ['this']
# this plane -> ['flying']
# plane flying -> ['in']
# in an -> ['insect-like']
# an insect-like -> ['pattern?']
# insect-like pattern? -> ['Get']
# pattern? Get -> ['your']
# Get your -> ['nose']
# your nose -> ['in']
# nose in -> ['there.']
# in there. -> ["Don't"]
# there. Don't -> ['be']
# be afraid. -> ['Smell']
# afraid. Smell -> ['it.']
# Smell it. -> ['Full']
# it. Full -> ['reverse!']
# reverse! Just -> ['drop']
# Just drop -> ['it.']
# drop it. -> ['Be']
# it. Be -> ['a']
# Be a -> ['part']
# it. Aim -> ['for']
# Aim for -> ['the']
# the center! -> ['Now']
# center! Now -> ['drop']
# Now drop -> ['it']
# drop it -> ['in!']
# it in! -> ['Drop']
# in! Drop -> ['it']
# Drop it -> ['in,']
# in, woman! -> ['Come']
# woman! Come -> ['on,']
# on, already. -> ['Barry,']
# already. Barry, -> ['we']
# Barry, we -> ['did']
# we did -> ['it!']
# did it! -> ['You']
# You taught -> ['me']
# taught me -> ['how']
# me how -> ['to']
# to fly! -> ['Yes.']
# fly! Yes. -> ['No']
# Yes. No -> ['high-five!']
# No high-five! -> ['Right.']
# high-five! Right. -> ['Barry,']
# Right. Barry, -> ['it']
# Barry, it -> ['worked!']
# it worked! -> ['Did']
# worked! Did -> ['you']
# giant flower? -> ['What', 'Where?']
# flower? What -> ['giant']
# What giant -> ['flower?']
# flower? Where? -> ['Of']
# Where? Of -> ['course']
# Of course -> ['I']
# course I -> ['saw']
# I saw -> ['the']
# saw the -> ['flower!']
# flower! That -> ['was']
# was genius! -> ['Thank']
# genius! Thank -> ['you.']
# you. But -> ["we're"]
# But we're -> ['not']
# we're not -> ['done']
# not done -> ['yet.']
# done yet. -> ['Listen,']
# yet. Listen, -> ['everyone!']
# Listen, everyone! -> ['This']
# everyone! This -> ['runway']
# This runway -> ['is']
# runway is -> ['covered']
# is covered -> ['with']
# covered with -> ['the']
# last pollen -> ['from']
# pollen from -> ['the']
# last flowers -> ['available']
# flowers available -> ['anywhere']
# available anywhere -> ['on']
# anywhere on -> ['Earth.']
# Earth. That -> ['means']
# That means -> ['this']
# means this -> ['is']
# is our -> ['Last', 'moment!']
# our Last -> ['Chance.']
# Last Chance. -> ["We're"]
# Chance. We're -> ['the']
# only ones -> ['who']
# ones who -> ['make']
# who make -> ['honey,']
# make honey, -> ['pollinate']
# honey, pollinate -> ['flowers']
# pollinate flowers -> ['and']
# and dress -> ['like']
# this. If -> ["we're"]
# If we're -> ['gonna']
# we're gonna -> ['survive']
# gonna survive -> ['as']
# survive as -> ['a']
# species, this -> ['is']
# our moment! -> ['What']
# moment! What -> ['do']
# you say? -> ['Are']
# say? Are -> ['we']
# we going -> ['to']
# be bees, -> ['or']
# bees, or -> ['just']
# or just -> ['Museum']
# just Museum -> ['of']
# Museum of -> ['Natural']
# of Natural -> ['History']
# Natural History -> ['keychains?']
# History keychains? -> ["We're"]
# keychains? We're -> ['bees!']
# We're bees! -> ['Keychain!']
# bees! Keychain! -> ['Then']
# Keychain! Then -> ['follow']
# Then follow -> ['me!']
# follow me! -> ['Except']
# me! Except -> ['Keychain.']
# Except Keychain. -> ['Hold']
# Keychain. Hold -> ['on,']
# Hold on, -> ['Barry.']
# on, Barry. -> ['Here.']
# Barry. Here. -> ["You've"]
# Here. You've -> ['earned']
# You've earned -> ['this.']
# earned this. -> ['Yeah!']
# this. Yeah! -> ["I'm"]
# Yeah! I'm -> ['a']
# Pollen Jock! -> ['And']
# Jock! And -> ["it's"]
# a perfect -> ['fit.']
# perfect fit. -> ['All']
# fit. All -> ['I']
# All I -> ['gotta', 'needed']
# do are -> ['the']
# are the -> ['sleeves.']
# the sleeves. -> ['Oh,']
# sleeves. Oh, -> ['yeah.']
# yeah. That's -> ['our']
# our Barry. -> ['Mom!']
# Barry. Mom! -> ['The']
# Mom! The -> ['bees']
# The bees -> ['are']
# are back! -> ['If']
# back! If -> ['anybody']
# If anybody -> ['needs']
# anybody needs -> ['to']
# a call, -> ["now's"]
# call, now's -> ['the']
# now's the -> ['time.']
# a feeling -> ["we'll"]
# feeling we'll -> ['be']
# we'll be -> ['working']
# be working -> ['late']
# working late -> ['tonight!']
# late tonight! -> ["Here's"]
# tonight! Here's -> ['your']
# Here's your -> ['change.']
# your change. -> ['Have']
# change. Have -> ['a']
# Have a -> ['great', 'great']
# great afternoon! -> ['Can', 'Barry,']
# afternoon! Can -> ['I']
# I help -> ["who's", "who's"]
# help who's -> ['next?', 'next?']
# who's next? -> ['Would', 'All']
# next? Would -> ['you']
# like some -> ['honey']
# honey with -> ['that?']
# with that? -> ['It']
# that? It -> ['is']
# It is -> ['bee-approved.']
# is bee-approved. -> ["Don't"]
# bee-approved. Don't -> ['forget']
# Don't forget -> ['these.']
# forget these. -> ['Milk,']
# these. Milk, -> ['cream,']
# Milk, cream, -> ['cheese,']
# cream, cheese, -> ["it's"]
# cheese, it's -> ['all']
# it's all -> ['me.']
# all me. -> ['And']
# And I -> ["don't"]
# see a -> ['nickel!']
# a nickel! -> ['Sometimes']
# nickel! Sometimes -> ['I']
# just feel -> ['like']
# feel like -> ['a']
# of meat! -> ['I']
# meat! I -> ['had']
# no idea. -> ['Barry,']
# idea. Barry, -> ["I'm"]
# sorry. Have -> ['you']
# you got -> ['a']
# a moment? -> ['Would']
# moment? Would -> ['you']
# you excuse -> ['me?']
# excuse me? -> ['My']
# me? My -> ['mosquito']
# My mosquito -> ['associate']
# mosquito associate -> ['will']
# associate will -> ['help']
# will help -> ['you.']
# help you. -> ['Sorry']
# you. Sorry -> ["I'm"]
# Sorry I'm -> ['late.']
# I'm late. -> ["He's"]
# late. He's -> ['a']
# He's a -> ['lawyer']
# lawyer too? -> ['I']
# too? I -> ['was']
# was already -> ['a']
# already a -> ['blood-sucking']
# a blood-sucking -> ['parasite.']
# blood-sucking parasite. -> ['All']
# parasite. All -> ['I']
# I needed -> ['was']
# needed was -> ['a']
# a briefcase. -> ['Have']
# briefcase. Have -> ['a']
# afternoon! Barry, -> ['I']
# got this -> ['huge']
# this huge -> ['tulip']
# huge tulip -> ['order,']
# tulip order, -> ['and']
# order, and -> ['I']
# get them -> ['anywhere.']
# them anywhere. -> ['No']
# anywhere. No -> ['problem,']
# No problem, -> ['Vannie.']
# problem, Vannie. -> ['Just']
# Vannie. Just -> ['leave']
# Just leave -> ['it']
# leave it -> ['to']
# me. You're -> ['a']
# You're a -> ['lifesaver,']
# a lifesaver, -> ['Barry.']
# lifesaver, Barry. -> ['Can']
# Barry. Can -> ['I']
# next? All -> ['right,']
# right, scramble, -> ['jocks!']
# scramble, jocks! -> ["It's"]
# jocks! It's -> ['time']
# It's time -> ['to']
# time to -> ['fly.']
# fly. Thank -> ['you,']
# Thank you, -> ['Barry!']
# you, Barry! -> ['That']
# Barry! That -> ['bee']
# That bee -> ['is']
# is living -> ['my']
# living my -> ['life!']
# life! Let -> ['it']
# Let it -> ['go,', 'all']
# it go, -> ['Kenny.']
# go, Kenny. -> ['When']
# Kenny. When -> ['will']
# When will -> ['this']
# this nightmare -> ['end?!']
# nightmare end?! -> ['Let']
# end?! Let -> ['it']
# it all -> ['go.']
# all go. -> ['Beautiful']
# go. Beautiful -> ['day']
# Beautiful day -> ['to']
# day to -> ['fly.']
# fly. Sure -> ['is.']
# Sure is. -> ['Between']
# is. Between -> ['you']
# Between you -> ['and']
# and me, -> ['I']
# me, I -> ['was']
# was dying -> ['to']
# dying to -> ['get']
# get out -> ['of']
# that office. -> ['You']
# office. You -> ['have']
# bee! Me? -> ['Hold']
# Me? Hold -> ['it.']
# Hold it. -> ["Let's", "I'm"]
# it. Let's -> ['just']
# Let's just -> ['stop']
# just stop -> ['for']
# stop for -> ['a']
# second. Hold -> ['it.']
# it. I'm -> ['sorry.']
# sorry. I'm -> ['sorry,']
# sorry, everyone. -> ['Can']
# everyone. Can -> ['we']
# Can we -> ['stop']
# we stop -> ['here?']
# stop here? -> ["I'm"]
# here? I'm -> ['not']
# not making -> ['a']
# making a -> ['major']
# a major -> ['life']
# major life -> ['decision']
# life decision -> ['during']
# decision during -> ['a']
# during a -> ['production']
# a production -> ['number!']
# production number! -> ['All']
# number! All -> ['right.']
# right. Take -> ['ten,']
# Take ten, -> ['everybody.']
# ten, everybody. -> ['Wrap']
# everybody. Wrap -> ['it']
# Wrap it -> ['up,']
# up, guys. -> ['I']
# guys. I -> ['had']
# had virtually -> ['no']
# virtually no -> ['rehearsal']
# no rehearsal -> ['for']
# rehearsal for -> ['that.']

# %%
# Generate some text
print("Generated text:")
print(generate_text(chain))
# Out:
# Generated text:
# isn't the bee is living my life! Let it all go. Beautiful day to fly. Am I koo-koo-kachoo, or is this place? A bee's got a brain the size of

# %% [markdown]
# ## Student Tasks
#
# 1. Basic Implementation:
#    - Try changing the order parameter in build_markov_chain
#    - What happens with order=1 vs order=3?

# %%
# Task 1: Experiment with different orders
print("\nOrder 1:")
chain1 = build_markov_chain(your_text, order=1)
print(generate_text(chain1))

print("\nOrder 3:")
chain3 = build_markov_chain(your_text, order=3)
print(generate_text(chain3))
# Out:
# Order 1:
# know! It's just a part of destruction! You snap out of Roses parade of coffee! Anyway, this means? All rise! The Princess and Adam here in a stirrer? No wonder
#
# Order 3:
# let's drop this tin can on the blacktop. Where? I can't see anything. Can you? No, nothing. It's all cloudy. Come on. You got to be kidding me! Mooseblood's about

# %% [markdown]
# 2. Use Your Own Text:
#    Below, try using a different text source. You could use:
#    - Song lyrics
#    - Book excerpts
#    - Movie quotes

# %%
# Task 2: Add your own text here
your_text = """
According to all known laws of aviation, there is no way a bee should be able to fly.
Its wings are too small to get its fat little body off the ground.
The bee, of course, flies anyway because bees don't care what humans think is impossible.
Yellow, black. Yellow, black. Yellow, black. Yellow, black.
Ooh, black and yellow!
Let's shake it up a little.
Barry! Breakfast is ready!
Coming!
Hang on a second.
Hello?
Barry?
Adam?
Can you believe this is happening?
I can't.
I'll pick you up.
Looking sharp.
Use the stairs, Your father paid good money for those.
Sorry. I'm excited.
Here's the graduate.
We're very proud of you, son.
A perfect report card, all B's.
Very proud.
Ma! I got a thing going here.
You got lint on your fuzz.
Ow! That's me!
Wave to us! We'll be in row 118,000.
Bye!
Barry, I told you, stop flying in the house!
Hey, Adam.
Hey, Barry.
Is that fuzz gel?
A little. Special day, graduation.
Never thought I'd make it.
Three days grade school, three days high school.
Those were awkward.
Three days college. I'm glad I took a day and hitchhiked around The Hive.
You did come back different.
Hi, Barry. Artie, growing a mustache? Looks good.
Hear about Frankie?
Yeah.
You going to the funeral?
No, I'm not going.
Everybody knows, sting someone, you die.
Don't waste it on a squirrel.
Such a hothead.
I guess he could have just gotten out of the way.
I love this incorporating an amusement park into our day.
That's why we don't need vacations.
Boy, quite a bit of pomp under the circumstances.
Well, Adam, today we are men.
We are!
Bee-men.
Amen!
Hallelujah!
Students, faculty, distinguished bees,
please welcome Dean Buzzwell.
Welcome, New Hive City graduating class of 9:15.
That concludes our ceremonies And begins your career at Honex Industries!
Will we pick our job today?
I heard it's just orientation.
Heads up! Here we go.
Keep your hands and antennas inside the tram at all times.
Wonder what it'll be like?
A little scary.
Welcome to Honex, a division of Honesco and a part of the Hexagon Group.
This is it!
Wow.
Wow.
We know that you, as a bee, have worked your whole life to get to the point where you can work for your whole life.
Honey begins when our valiant Pollen Jocks bring the nectar to The Hive.
Our top-secret formula is automatically color-corrected, scent-adjusted and bubble-contoured into this soothing sweet syrup with its distinctive golden glow you know as... Honey!
Me?
Hold it. Let's just stop for a second. Hold it.
I'm sorry. I'm sorry, everyone. Can we stop here?
I'm not making a major life decision during a production number!
All right. Take ten, everybody. Wrap it up, guys.
I had virtually no rehearsal for that.

"""

# %% [markdown]
# 3. Advanced Implementation:
#    Add temperature-based sampling to control randomness

# %%
def generate_text_with_temperature(chain, temperature=1.0, num_words=30):
    """
    Generate text with temperature-based sampling.
    Lower temperature = more conservative/predictable
    Higher temperature = more random/creative

    Args:
        chain (dict): Markov chain
        temperature (float): Controls randomness (0.1 to 2.0 recommended)
        order (int): Length of state tuples
        num_words (int): Number of words to generate
    """
    words = list(random.choice(list(chain.keys())))
    order = len(list(chain.keys())[3])

    for _ in range(num_words - order):
        state = tuple(words[-order:])
        if state in chain:
            # Count frequencies of next words
            next_words = chain[state]
            word_counts = defaultdict(int)
            for word in next_words:
                word_counts[word] += 1

            # Apply temperature
            weights = [count ** (1.0 / temperature) for count in word_counts.values()]
            total = sum(weights)
            weights = [w/total for w in weights]

            # Choose next word based on weighted probabilities
            next_word = random.choices(list(word_counts.keys()), weights=weights)[0]
            words.append(next_word)
        else:
            break

    return ' '.join(words)

# Try different temperatures
print("\nLow temperature (more predictable):")
print(generate_text_with_temperature(chain, temperature=0.1))

print("\nHigh temperature (more random):")
print(generate_text_with_temperature(chain, temperature=100.0))
# Out:
# Low temperature (more predictable):
# That's life! Oh, this is our moment! What do you think that is? You know, I'm gonna get an ant tattoo! Let's open some honey with that? It is bee-approved.
#
# High temperature (more random):
# to rehearse your part and learn your lines, sir? Watch it, Benson! I could really get in trouble? You a mosquito, you in trouble. It's very hard to concentrate with

# %% [markdown]
# ## Challenge Tasks:
#
# 1. Implement a function to analyze the Markov chain:
#    - Count the number of unique states
#    - Find the most common transitions
#    - Calculate the average number of possible next words for each state

# %%
def analyze_chain(chain):
    """
    Analyze properties of the Markov chain.

    Args:
        chain (dict): Markov chain to analyze
    """
    num_states = len(chain)
    total_transitions = sum(len(next_words) for next_words in chain.values())
    avg_transitions = total_transitions / num_states if num_states > 0 else 0

    # Find most common next word for each state
    most_common = {}
    for state, next_words in chain.items():
        word_counts = defaultdict(int)
        for word in next_words:
            word_counts[word] += 1
        most_common[state] = max(word_counts.items(), key=lambda x: x[1])

    print(f"Number of unique states: {num_states}")
    print(f"Average transitions per state: {avg_transitions:.2f}")
    print("\nMost common transitions:")
    for state, (word, count) in list(most_common.items())[:5]:  # Show top 5
        print(f"{' '.join(state)} -> {word} (count: {count})")

# Analyze our chain
print("\nChain Analysis:")
analyze_chain(chain)
# Out:
# Chain Analysis:
# Number of unique states: 7552
# Average transitions per state: 1.21
#
# Most common transitions:
# According to -> all (count: 1)
# to all -> known (count: 1)
# all known -> laws (count: 1)
# known laws -> of (count: 1)
# laws of -> aviation, (count: 1)

# %% [markdown]
# ## Further Exploration:
#
# Other ideas to try:
# 1. Modify the code to preserve punctuation
# 2. Add start-of-sentence and end-of-sentence tokens
# 3. Implement bi-directional generation
# 4. Create a chain that works with characters instead of words
# 5. Add input validation and error handling
